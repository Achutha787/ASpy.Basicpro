# %%
#1)
print("Hello Python!")
# Out:
# Hello Python!

# %%
#2)
a=45
b=34
print(a+b)
print(a/b)
# Out:
# 79
# 1.3235294117647058

# %%
#3)
b=3
h=5
print("area of a triangle = ", (h*b)/2)
# Out:
# area of a triangle =  7.5

# %%
#4)
A = 50
B = 100
A,B = B,A
print("Value of A after swapping is ", A)
print("Value of B after swapping is ", B)
# Out:
# Value of A after swapping is  100
# Value of B after swapping is  50

# %% [markdown]
# import randomn
# print(random.randint(0,100)

# %%
#5)
import random
random.seed(3)
print(random.random())
# Out:
# 0.23796462709189137
